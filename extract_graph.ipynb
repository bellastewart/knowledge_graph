# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random
import ollama

## Input data directory
data_dir = "PFAS_test"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
#loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=2500, #1500 
    chunk_overlap=0, #150 
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
# Number of chunks =  26
# 2.1.Chemicals. Thechemicals usedinthisstudyare
# described inTextS1.
# 2.2.Synthesis ofnFe0andS-nFe0.Unmodified nFe0and
# S-nFe0particleswithcontrollable Sspeciation wereprepared
# according toareportedone-stepmethod.32,36Briefly,200mL
# of34gL−1NaBH4andacertainamountofNa2S·9H2O(or
# Na2S2O4)wasdropwise addedintoaFeCl3solutionunder
# continuous stirring(350rpm)andnitrogen purging(0.4L
# min−1).ThedosedNaBH4/Femolarratiowas5,andthe
# dosedS/Femolarratioswere0and0.14,respectively. The
# resultingparticleswererapidlywashed,magnetically separated,
# andvacuum-dried at60°Cfor8h.Thevacuumwasreleasedover2htostabilizetheparticlesbeforetheyweresealedand
# storedinananerobicglovebox.
# 2.3.BatchExperiments. Thebatchreactivity experiments
# wereconducted in170mLserumbottlescontaining 100mLof
# solution and70mLofheadspace. Overall, twotypical
# scenarios forthecoexistence ofTCE-NAPL oraqueousTCE
# withPFASsingroundwater wereconsidered, representing
# common cocontamination sitesnearandrelatively farfromthe
# source,respectively. Sincetheconcentration ofPFASswas
# generally around100 μgL−1intheAFFFs-impacted
# groundwater,1,2wherechlorinated solventsmaycoexist,this
# concentration ofPFOAorPFOSwasusedtoprobetheir
# potential impactsontheTCEdegradation. Fortheaqueous
# TCEscenario, theinitialTCEconcentration inthereaction
# bottlewas∼70 μMandtheironmaterials were1.0gL−1.The
# simulation ofTCE-NAPL scenariowasaccording toprevious
# work,44100 μLofpureTCEwasinjectedinto100mLof
# deionized water,alongwiththeinjectionof1mLPFASsstock
# solution(10mgL−1),andequilibrated toformaTCE-NAPL
# phasealongwith100μgL−1PFASs.Subsequently, 0.1gof
# ironmaterials wasaddedtothebottletoinitiatetheTCE-
# NAPLdegradation. Inallexperiments, deoxygenated deionized
# (DI)waterafter1hofN2purgingwasused,thebottleswere
# cappedbyTeflonMininertvalves,andtheinitialpHwas6.0±
# 0.2androtatedonanend-overend rotator(40rpm)for8days
# at25±2°C.TheimpactsofSspeciation andcoexisting
# PFASsonthemasstransferofmaterials aredescribed indetail
# inTextS2.
# Toassesstheperformance ofironmaterials under
# environmentally relevant conditions, thereactivity and
# selectivity ofmaterials withTCEwerealsomonitored inreal
# groundwater sampled fromawellinHangzhou, China.
# Corresponding physicochemical parameters aresummarized
# inTableS1.Thedetailedexperimental processwasthesameas
# fortheabovebatchexperiments.
# 2.4.Characterizations. TheFe0contentwascalculated by
# measuring thegenerated H2aftertheacidification of∼15mg
# ofeachironmaterialin10mLofHCl.TheactualS/Femolar

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (26, 4)
#                                                 text  \
# 0  ImpactsofPerfluoroalkyl Substances onAqueous a...
# 1  presentasnonaqueous phaseliquid(NAPL)whendisch...
# 2  aqueousTCEandTCE-NAPL bynanoscale zerovalent i...
# 3  2.1.Chemicals. Thechemicals usedinthisstudyare...
# 4  ratioofeachironmaterialwasdetermined byinducti...
#
#                                source  page                          chunk_id
# 0  data_input/PFAS_test/PFAS_test.pdf     0  0b24de36ca004f6b8524bc0ec052d492
# 1  data_input/PFAS_test/PFAS_test.pdf     0  a726ae82688143449e250baeb7ee682a
# 2  data_input/PFAS_test/PFAS_test.pdf     1  14fdf5a2d65f474d8e378c293f56dd57
# 3  data_input/PFAS_test/PFAS_test.pdf     1  8539000bd313470d9cdae463e74ba32a
# 4  data_input/PFAS_test/PFAS_test.pdf     1  a311fe74731d4e6f80867df269b5f9fa

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# Here is the output as a list of JSON objects based on the provided context:
#
# [
#   {
#     "node_1": "Perfluoroalkyl substances (PFASs)",
#     "node_2": "Nonaqueous phaseliquid (NAPL)",
#     "edge": "Co-occurrence in groundwater and soil at fire-fighting and military sites due to the use of aqueous film-forming foams (AFFFs) containing PFASs."
#   },
#   {
#     "node_1": "Perfluoroalkyl substances (PFASs)",
#     "node_2": "Sulfidized nanoscale zerovalent iron (S-nFe0)",
#     "edge": "Interactions with S-nFe0, where surface-adsorbed PFASs block reactivesites and inhibit aqueous trichloroethylene (TCE) dechlorination."
#   },
#   {
#     "node_1": "Perfluoroalkyl substances (PFASs)",
#     "node_2": "Trichloroethylene (TCE)-NAPL",
#     "edge": "Enrichment at the NAPL-water interface, which exposes reactivesites for accelerated TCE dechlorination."
#   },
#   {
#     "node_1": "Sulfidized nanoscale zerovalent iron (S-nFe0)",
#     "node_2": "Trichloroethylene (TCE)-NAPL",
#     "edge": "Higher reactivity (up to 1.8-fold) and higher electrochemical efficiency (up to 99%) for TCE-NAPL dechlorination due to the PFASs-induced phenomenon of enrichment at the NAPL-water interface."
#   },
#   {
#     "node_1": "Sulfidized nanoscale zerovalent iron (S-nFe0)",
#     "node_2": "Nonaqueous phaseliquid (NAPL)-water interface",
#     "edge": "Morereadily enrichment and higher reactivity and selectivity than S-nFe0 for TCE-NAPL dechlorination, regardless of coexisting PFASs."
# ]
#
# ERROR ### Here is the buggy response:  Here is the output as a list of JSON objects based on the provided context:
#
# [
#   {
#     "node_1": "Perfluoroalkyl substances (PFASs)",
#     "node_2": "Nonaqueous phaseliquid (NAPL)",
#     "edge": "Co-occurrence in groundwater and soil at fire-fighting and military sites due to the use of aqueous film-forming foams (AFFFs) containing PFASs."
#   },
#   {
#     "node_1": "Perfluoroalkyl substances (PFASs)",
#     "node_2": "Sulfidized nanoscale zerovalent iron (S-nFe0)",
#     "edge": "Interactions with S-nFe0, where surface-adsorbed PFASs block reactivesites and inhibit aqueous trichloroethylene (TCE) dechlorination."
#   },
#   {
#     "node_1": "Perfluoroalkyl substances (PFASs)",
#     "node_2": "Trichloroethylene (TCE)-NAPL",
#     "edge": "Enrichment at the NAPL-water interface, which exposes reactivesites for accelerated TCE dechlorination."
#   },
#   {
#     "node_1": "Sulfidized nanoscale zerovalent iron (S-nFe0)",
#     "node_2": "Trichloroethylene (TCE)-NAPL",
#     "edge": "Higher reactivity (up to 1.8-fold) and higher electrochemical efficiency (up to 99%) for TCE-NAPL dechlorination due to the PFASs-induced phenomenon of enrichment at the NAPL-water interface."
#   },
#   {
#     "node_1": "Sulfidized nanoscale zerovalent iron (S-nFe0)",
#     "node_2": "Nonaqueous phaseliquid (NAPL)-water interface",
#     "edge": "Morereadily enrichment and higher reactivity and selectivity than S-nFe0 for TCE-NAPL dechlorination, regardless of coexisting PFASs."
# ]
#
#
# [
#    {
#        "node_1": "PFAS",
#        "node_2": "NAPL-water interface",
#        "edge": "Accumulate easily at the fluid-fluid interface, such as NAPL-water interfaces or being partitioned into the bulk NAPL phase. This distribution leads to an increase in the retention of PFASs and reduces NAPL-water interfacial tensions, affecting NAPL dissolution."
#    }, {
#        "node_1": "PFOS",
#        "node_2": "Aqueous TCE",
#        "edge": "Inhibits slightly the adsorption of PFOS on colloidal activated carbon."
#    }
# ][
#    {
#        "node_1": "aqueous TCE",
#        "node_2": "S-nFe0",
#        "edge": "improved degradation performance of S-nFe0 for aqueous TCE compared to nFe0 due to altered physicochemical properties such as increased hydrophobicity and inhibited adsorption through sulfidation"
#    },
#    {
#        "node_1": "TCE-NAPL",
#        "node_2": "S-nFe0",
#        "edge": "limited mechanistic information available on degradation of TCE-NAPL by S-nFe0, especially in the presence of PFASs"
#    },
#    {
#        "node_1": "PFOS",
#        "node_2": "S-nFe0",
#        "edge": "impact of coexisting PFOS on performance of S-nFe0 for aqueous TCE and TCE-NAPL degradation through adsorption via hydrophobic and electrostatic interactions affected by surface corrosion products of nFe0 particles"
#    },
#    {
#        "node_1": "PFOS",
#        "node_2": "nFe0",
#        "edge": "adsorption of PFOS by both nFe0 and S-nFe0 through hydrophobic and electrostatic interactions, which are affected by the properties of PFASs and surface corrosion products of nFe0 particles"
#    },
#    {
#        "node_1": "S-nFe0",
#        "node_2": "PFOS",
#        "edge": "impact of coexisting PFASs on TCE degradation by S-nFe0, but further investigation is required"
#    },
#    {
#        "node_1": "S-nFe0",
#        "node_2": "PFOA",
#        "edge": "impact of coexisting PFOA on performance of S-nFe0 for aqueous TCE and TCE-NAPL degradation through adsorption via hydrophobic and electrostatic interactions affected by surface corrosion products of nFe0 particles"
#    },
#    {
#        "node_1": "S-nFe0",
#        "node_2": "PFOA",
#        "edge": "impact of coexisting PFOA on TCE degradation by S-nFe0, but further investigation is required"
#    },
#    {
#        "node_1": "PFOS",
#        "node_2": "S content",
#        "edge": "crucial factor that determines the structure−property−activity relationships of materials and S speciation plays a more significant role in hydrophobicity compared to S content"
#    },
#    {
#        "node_1": "PFOS",
#        "node_2": "FeSorFeS2",
#        "edge": "controllable S speciation (mainly FeSorFeS2) synthesized and characterized to assess their impact on materials' performance for aqueous TCE and TCE-NAPL degradation"
#    },
#    {
#        "node_1": "TCE",
#        "node_2": "nFe0",
#        "edge": "widely studied stoichiometric electronexcess conditions representing remediation scenarios for aqueous TCE in contaminated plume"
#    },
#    {
#        "node_1": "coexisting PFASs",
#        "node_2": "nFe0",
#        "edge": "adsorption of coexisting PFASs by both nFe0 and S-nFe0 through hydrophobic and electrostatic interactions affected by the properties of PFASs and surface corrosion products of nFe0 particles"
#    }
# ]
# [
#    {
#        "node_1": "TCE",
#        "node_2": "Fe materials",
#        "edge": "The batch experiments showed the degradation of TCE in the presence of iron materials for both aqueous and NAPL scenarios. The Fe0 content was calculated by measuring the generated H2 after acidification of the iron materials. This experiment was conducted in real groundwater samples from Hangzhou, China, with corresponding physicochemical parameters summarized in TableS1."
#    },
#    {
#        "node_1": "TCE",
#        "node_2": "PFASs",
#        "edge": "Both TCE and PFASs were present in the aqueous scenario, with an initial concentration of ∼70 μM for TCE and around 100 μgL−1 for PFASs. The simulation of the TCE-NAPL scenario involved injecting pure TCE into deionized water along with the injection of the 10 mgL−1 PFASs stock solution, which was then equilibrated to form a TCE-NAPL phase. The impact of S speciation and coexisting PFASs on the mass transfer of materials is described in detail in TextS2."
#    },
#    {
#        "node_1": "Fe materials",
#        "node_2": "TCE-NAPL",
#        "edge": "In the TCE-NAPL scenario, 0.1 g of iron materials was added to initiate degradation. The initial pH was 6.0±0.2 and the bottles were rotated on an end-over-end rotator at 40 rpm for 8 days at 25±2°C."
#    },
#    {
#        "node_1": "Fe materials",
#        "node_2": "S speciation",
#        "edge": "The effect of S speciation on the mass transfer of materials was assessed by varying the dose of Na2S·9H2O or Na2S2O4 in a one-step method, which resulted in controllable S speciation in unmodified nFe0 and S-nFe0 particles. The Fe0 content was calculated by measuring the generated H2 after acidification."
#    },
# ]
#
# ERROR ### Here is the buggy response:  [
#    {
#        "node_1": "TCE",
#        "node_2": "Fe materials",
#        "edge": "The batch experiments showed the degradation of TCE in the presence of iron materials for both aqueous and NAPL scenarios. The Fe0 content was calculated by measuring the generated H2 after acidification of the iron materials. This experiment was conducted in real groundwater samples from Hangzhou, China, with corresponding physicochemical parameters summarized in TableS1."
#    },
#    {
#        "node_1": "TCE",
#        "node_2": "PFASs",
#        "edge": "Both TCE and PFASs were present in the aqueous scenario, with an initial concentration of ∼70 μM for TCE and around 100 μgL−1 for PFASs. The simulation of the TCE-NAPL scenario involved injecting pure TCE into deionized water along with the injection of the 10 mgL−1 PFASs stock solution, which was then equilibrated to form a TCE-NAPL phase. The impact of S speciation and coexisting PFASs on the mass transfer of materials is described in detail in TextS2."
#    },
#    {
#        "node_1": "Fe materials",
#        "node_2": "TCE-NAPL",
#        "edge": "In the TCE-NAPL scenario, 0.1 g of iron materials was added to initiate degradation. The initial pH was 6.0±0.2 and the bottles were rotated on an end-over-end rotator at 40 rpm for 8 days at 25±2°C."
#    },
#    {
#        "node_1": "Fe materials",
#        "node_2": "S speciation",
#        "edge": "The effect of S speciation on the mass transfer of materials was assessed by varying the dose of Na2S·9H2O or Na2S2O4 in a one-step method, which resulted in controllable S speciation in unmodified nFe0 and S-nFe0 particles. The Fe0 content was calculated by measuring the generated H2 after acidification."
#    },
# ]
#
#
# [
#    {
#        "node_1": "ratio of each iron material",
#        "node_2": "ICP-OES",
#        "edge": "determined by inductively coupled plasma-optical emission spectroscopy (ICP-OES)"
#    },
#    {
#        "node_1": "nFe0 and S-nFe0 particles",
#        "node_2": "morphology",
#        "edge": "characterized by high-angle annular dark-field scanning transmission electron microscopy (HAADF-STEM)"
#    },
#    {
#        "node_1": "nFe0 and S-nFe0 particles",
#        "node_2": "localized elemental distributions",
#        "edge": "characterized by energy-dispersive X-rayspectrometry (EDX)"
#    },
#    {
#        "node_1": "iron materials",
#        "node_2": "crystalline structure",
#        "edge": "analyzed by X-ray diffraction (XRD)"
#    },
#    {
#        "node_1": "iron materials",
#        "node_2": "coordination environment",
#        "edge": "understood by X-ray absorption fine structure (XAFS) spectroscopy"
#    },
#    {
#        "node_1": "iron materials",
#        "node_2": "physicochemical properties",
#        "edge": "assessed by electrochemical impedance spectroscopy (EIS) and water contact angle (WCA)"
#    },
#    {
#        "node_1": "H2, TCE, and its degradation products",
#        "node_2": "headspace",
#        "edge": "analyzed using gas chromatography with thermal conductivity and flame ionization detectors (TextS4)"
#    }
# ][
#   {
#     "node_1": "dechlorination products",
#     "node_2": "TCE-NAPL",
#     "edge": "The degradation of TCE-NAPL was calculated by quantifying TCE degradation products with time due to the presence of TCE-NAPL and use of stoichiometrically limited amounts of iron materials compared to TCE, and the change in headspace TCE concentration during the TCE degradation experiments was minimal."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "dechlorination products",
#     "edge": "Were calculated according to their Henry's law constant to obtain their total concentrations in the reactors (Table S2)."
#   },
#   {
#     "node_1": "Fe0",
#     "node_2": "TCE-NAPL degradation",
#     "edge": "Was calculated after 90% elimination of TCE and 8 days of degradation, respectively."
#   },
#   {
#     "node_1": "Fe0",
#     "node_2": "Fe0 content",
#     "edge": "Unmodified nFe0 exhibited atypical chain-like structure of spherical nanoparticles with an oxidized shell, and impregnating sulfur into the particles increased the primary particle size. Compared to materials synthesized with sulfide precursor, materials synthesized with dithionite precursor showed relatively stronger intensity on the HAADF images, a higher intraparticle coexistence probability of Fe and S on the elemental maps, and a higher Fe0 content (80% vs 62%) despite their [S/Fe] measured being close."
#   },
#   {
#     "node_1": "FeK-edge EXAFS spectrum",
#     "node_2": "Improved shell fit of Fe0",
#     "edge": "The addition of Fe−S scattering paths from mackinawite (FeS) and pyrite (FeS2) indicated that the S speciation of S-nFe0 materials synthesized with sulfide and dithionite precursors was primary FeS and FeS2, respectively."
#   },
#   {
#     "node_1": "Fe0 body-centered cubic (BCC)",
#     "node_2": "XRD patterns",
#     "edge": "The Fe0 peak shifts in the XRD patterns indicated that the S impregnation changed the Fe0 BCC structure."
#   }
# ][
#    {
#       "node_1": "structure",
#       "node_2": "variedcrystallinities",
#       "edge": "The modulated geometric structure obtained after the incorporation of different S species (Figure 1f) could affect materials' physicochemical properties."
#    },
#    {
#       "node_1": "structure",
#       "node_2": "latticeexpansion",
#       "edge": "The lattice constant of the Fe0 BCC structure calculated from XRD patterns and Fe-Fe bond length fitted from Fe K-edge EXAFS spectra (Figure 1f) for different materials is presented."
#    },
#    {
#       "node_1": "FeK-edgeEXAFSspectra",
#       "node_2": "latticeexpansion",
#       "edge": "The lattice constant of the Fe0 BCC structure calculated from XRD patterns and Fe-Fe bond length fitted from Fe K-edge EXAFS spectra (Figure 1d) for different materials is presented."
#    },
#    {
#       "node_1": "XRDpatterns",
#       "node_2": "latticeexpansion",
#       "edge": "The lattice constant of the Fe0 BCC structure calculated from XRD patterns (Figure 1e) for different materials is presented."
#    },
#    {
#       "node_1": "FeK-edgeEXAFSspectra",
#       "node_2": "S species",
#       "edge": "The Fe K-edge EXAFS spectra of S-nFe0 synthesized with adithionite precursor (Figure 1c) and unmodified nFe0 (Figure 1a) are presented."
#    },
#    {
#       "node_1": "S species",
#       "node_2": "variedcrystallinities",
#       "edge": "The modulated geometric structure obtained after the incorporation of different S species (Figure 1f) could affect materials' physicochemical properties."
#    },
#    {
#       "node_1": "EISdata",
#       "node_2": "resistance",
#       "edge": "The fitted resistance of EIS data (Figure 1g) for different materials is presented."
#    },
#    {
#       "node_1": "watercontactangle",
#       "node_2": "pellets",
#       "edge": "The water contact angle of pellets made from different materials (Figure 1h) is presented."
#    }
# ][
#    {
#        "node_1": "TCE",
#        "node_2": "S-nFe0",
#        "edge": "degradation followed pseudo-first-order kinetics, surface area normalized rates (kSA) for TCE by S-nFe0 were 4-6 times higher than that by unmodified nFe0 due to relatively lower impedance, faster electron transfer, and lower bandgap."
#    },
#    {
#        "node_1": "PFOA",
#        "node_2": "S-nFe0",
#        "edge": "coexistence inhibited TCE degradation for all materials studied, regardless of sulfidation and S speciation. The inhibitory effect of PFOA was more significant than that of PFOS for Fe0, while the inhibitory effects of PFOA and PFOS were similar for sulfidized versions."
#    },
#    {
#        "node_1": "PFOS",
#        "node_2": "S-nFe0",
#        "edge": "coexistence inhibited TCE degradation more significantly than that of PFOA for all materials studied, regardless of sulfidation and S speciation."
#    },
#    {
#        "node_1": "Hydrophobicity",
#        "node_2": "S-nFe0",
#        "edge": "presented higher water contact angle (125±3°) than Fe0 (33±3°) and nFe0-FeS (60±2°) materials, consistent with previous studies. This was probably due to the expansion of the lattice and lower bandgap of iron sulfides than iron oxides."
#    },
#    {
#        "node_1": "TCE",
#        "node_2": "PFASs",
#        "edge": "surface adsorption significantly increased the proportion of C2H4 generation for unmodified nFe0, but only slightly increased the proportions of C2H4 and C2H2 for TCE degradation by nFe0-FeS and nFe0-FeS2, respectively."
#    }
# ][
#    {
#       "node_1": "hydrophobicity of unmodified nFe0",
#       "node_2": "S-nFe0(FigureS6)",
#       "edge": "significantly increased"
#    },
#    {
#       "node_1": "hydrophobicity of S-nFe0(FigureS6)",
#       "node_2": "water",
#       "edge": "tends to inhibit"
#    },
#    {
#       "node_1": "electrontransfer and Hadsorption abilities of S-nFe0",
#       "node_2": "Sand its speciation",
#       "edge": "were likely dominated by Sand its speciation rather than adsorbed PFASs"
#    },
#    {
#       "node_1": "reactivity and Hadsorption for the hydrogenations of C2H4",
#       "node_2": "S-nFe0(FigureS6)",
#       "edge": "was lesser than S-nFe0(FigureS6), which tended to inhibit water"
#    },
#    {
#       "node_1": "impact of Sppeciation on reactivity",
#       "node_2": "Sppeciation and coexisting PFASs",
#       "edge": "on materials for degradations of aqueous TCE and TCE-NAPL (basic conditions: initial pH = 6.0 ± 0.2, T = 25 ± 2°C, coexisting PFOA or PFOS = 100 μg L−1, iron material = 1.0 g L−1)"
#    }
# ][
#   {
#     "node_1": "TCE-NAPL",
#     "node_2": "FeS2",
#     "edge": "Promotion effect of hydrophobic coexisting PFOS on TCE-NAPL degradation by FeS2 material is more significant than that with FeS material due to favored contact between the materials and NAPL enriched at the NAPL-water interface or distributed into the NAPL phase."
#   },
#   {
#     "node_1": "TCE-NAPL",
#     "node_2": "FeS",
#     "edge": "Promotion effect of hydrophobic coexisting PFOS on TCE-NAPL degradation by FeS material is observed due to favored contact between the materials and NAPL enriched at the NAPL-water interface or distributed into the NAPL phase."
#   },
#   {
#     "node_1": "TCE-NAPL",
#     "node_2": "Fe0",
#     "edge": "Promotion effect of hydrophobic coexisting PFOS and PFOA on TCE-NAPL degradation by Fe0 material is observed due to favored contact between the materials and NAPL enriched at the NAPL-water interface or distributed into the NAPL phase."
#   },
#   {
#     "node_1": "TCE-NAPL",
#     "node_2": "nFe0-FeS",
#     "edge": "Promotion effect of hydrophobic coexisting PFOS on TCE-NAPL degradation by nFe0-FeS material is observed due to favored contact between the materials and NAPL enriched at the NAPL-water interface or distributed into the NAPL phase."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "coexisting PFOA",
#     "edge": "Small amount of coexisting PFOA (100 μg L^-1) has a limited effect on the reactivity and product distribution of TCE-NAPL degradation, except for a trend of slightly accelerated TCE-NAPL degradation compared to that of 100 μg L^-1 PFOA."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "coexisting PFOA (500 and 1000 μg L^-1)",
#     "edge": "Higher concentrations of coexisting PFOA (500 and 1000 μg L^-1) did not significantly change the reactivity and product distribution of TCE-NAPL degradation, except for a trend of slightly accelerated TCE-NAPL degradation compared to that of 100 μg L^-1 PFOA."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "coexisting hydrophobic PFOS",
#     "edge": "Coexisting hydrophobic PFOS promotes the degradation of TCE-NAPL by all materials due to enrichment at the NAPL-water interface or distribution into the NAPL phase."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "coexisting hydrophilic PFOA",
#     "edge": "Coexisting hydrophilic PFOA did not significantly change the product distribution of TCE-NAPL degradation by materials."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "Fe0",
#     "edge": "The accumulation of unsaturated hydrocarbons under the TCE-NAPL condition indicates that the availability of electrons and H atoms for hydrogenation was quite low, and the contact of materials with NAPL could be a potential factor to alter the reactivity and product distribution."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "FeS",
#     "edge": "The accumulation of unsaturated hydrocarbons under the TCE-NAPL condition indicates that the availability of electrons and H atoms for hydrogenation was quite low, and the contact of materials with NAPL could be a potential factor to alter the reactivity and product distribution."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "nFe0-FeS",
#     "edge": "The accumulation of unsaturated hydrocarbons under the TCE-NAPL condition indicates that the availability of electrons and H atoms for hydrogenation was quite low, and the contact of materials with NAPL could be a potential factor to alter the reactivity and product distribution."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "FeS2",
#     "edge": "The accumulation of unsaturated hydrocarbons under the TCE-NAPL condition indicates that the availability of electrons and H atoms for hydrogenation was quite low, and the contact of materials with NAPL could be a potential factor to alter the reactivity and product distribution."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "Fe0",
#     "edge": "The improved reactivity of material (Fe0) with TCE-NAPL is more beneficial if the material is also selective for TCE reduction over water."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "FeS",
#     "edge": "The improved reactivity of material (FeS) with TCE-NAPL is more beneficial if the material is also selective for TCE reduction over water."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "nFe0-FeS",
#     "edge": "The improved reactivity of material (nFe0-FeS) with TCE-NAPL is more beneficial if the material is also selective for TCE reduction over water."
#   },
#   {
#     "node_1": "TCE",
#     "node_2": "FeS2",
#     "edge": "The improved reactivity of material (FeS2) with TCE-NAPL is more beneficial if the material is also selective for TCE reduction over water."
#   }
# ][
#    {
#        "node_1": "H2",
#        "node_2": "materials",
#        "edge": "quantifying the electrons consumed for H2 degradation to evaluate the selectivity of materials"
#    },
#    {
#        "node_1": "TCE",
#        "node_2": "materials",
#        "edge": "electron efficiency for aqueous TCE degradation by materials, with nFe0-FeS (46.4%) > nFe0 (4.7%)"
#    },
#    {
#        "node_1": "degradation products",
#        "node_2": "materials",
#        "edge": "electron efficiency for degradation of TCE and its degradation products to evaluate the selectivity of materials"
#    },
#    {
#        "node_1": "PFASs",
#        "node_2": "materials",
#        "edge": "effects on electron efficiency for aqueous TCE degradation by materials, with coexisting PFASs not significantly affecting electron efficiency"
#    },
#    {
#        "node_1": "PFASs",
#        "node_2": "TCE-NAPL degradation",
#        "edge": "limited effects on electron efficiency for TCE-NAPL degradation by materials, due to TCE being in excess compared to iron materials in the NAPL phase"
#    },
#    {
#        "node_1": "S-nFe0",
#        "node_2": "TCE-NAPL degradation",
#        "edge": "significantly increased electron efficiency for TCE-NAPL degradation by S-nFe0 materials, likely due to favored material-NAPL contact and inhibited water reactivity"
#    },
#    {
#        "node_1": "S-induced enhancements",
#        "node_2": "performance of S-nFe0",
#        "edge": "used to provide a more systematic comparison of the impact of S speciation and PFASs on material reactivity and selectivity, favoring rational design of S-nFe0 materials for aqueous and nonaqueous TCE degradation in the presence of emerging PFASs"
#    },
#    {
#        "node_1": "nFe0-FeS",
#        "node_2": "nFe0-FeS2",
#        "node_3": "electron efficiency for aqueous TCE degradation in the absence of PFASs",
#        "edge_1": "R value (theratios of reactivity and selectivity) of nFe0-FeS (R=6) was slightly higher than that of nFe0-FeS2 (R=4.5)",
#        "edge_2": "consistent with the relatively faster electron transfer of nFe0-FeS evaluated by electrochemical analysis and lower hydrophobicity that could favor dechlorination via hydrogenolysis and hydrogenation"
#    },
#    {
#        "node_1": "nFe0-FeS",
#        "node_2": "nFe0-FeS2",
#        "node_3": "electron efficiency for aqueous TCE degradation in the presence of PFOA",
#        "edge_1": "R values of nFe0-FeS and nFe0-FeS2 were similar to those in the absence of PFASs",
#        "edge_2": "however, these values stood out as higher in the presence of PFOS (9.5 and 6.3, respectively)"
#    },
#    {
#        "node_1": "nFe0-FeS",
#        "node_2": "nFe0-FeS2",
#        "node_3": "electron efficiency for aqueous TCE degradation in the presence of PFASs",
#        "edge_1": "set trends opposite to those in the absence of PFASs"
#    }
# ]

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                              node_1          node_2  \
# 2827  world-class health facilities  nhm strategies
# 2828  world-class health facilities     rural areas
# 2829  world-class health facilities    social norms
# 2830  world-class health facilities     urban areas
# 2831  world-class health facilities     urban slums
#
#                                                chunk_id  count  \
# 2827  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...     10
# 2828  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
# 2829  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
# 2830  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
# 2831  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...      2
#
#                       edge
# 2827  contextual proximity
# 2828  contextual proximity
# 2829  contextual proximity
# 2830  contextual proximity
# 2831  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                             node_1  \
# 0                      56 articles
# 1                             [54]
# 2                             [55]
# 3                  a bad situation
# 4            a worrisome new trend
# ..                             ...
# 753  world-class health facilities
# 754  world-class health facilities
# 755  world-class health facilities
# 756  world-class health facilities
# 757  world-class health facilities
#
#                                                node_2  \
# 0                         extensive literature search
# 1    increasing violence against healthcare personnel
# 2    increasing violence against healthcare personnel
# 3    increasing violence against healthcare personnel
# 4    increasing violence against healthcare personnel
# ..                                                ...
# 753                                    nhm strategies
# 754                                       rural areas
# 755                                      social norms
# 756                                       urban areas
# 757                                       urban slums
#
#                                               chunk_id                  edge  \
# 0    d7a3e5085c7f4de4bc28fb0bd9cb0a94,d7a3e5085c7f4...  contextual proximity
# 1    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# 2    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# 3    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# 4    640835e2521045a395ab6465cc1ba4ca,640835e252104...  contextual proximity
# ..                                                 ...                   ...
# 753  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 754  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 755  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 756  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
# 757  0857ab4513ad4383aed095bcf24506fa,0857ab4513ad4...  contextual proximity
#
#      count
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
# ..     ...
# 753     10
# 754      2
# 755      2
# 756      2
# 757      2
#
# [758 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (215,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  17
# [['56 articles', 'analysis', "corresponding authors' experiential knowledge", 'extensive literature search', 'peer-reviewed journals'], ['[54]', '[55]', 'a bad situation', 'a worrisome new trend', 'adequately compensated', 'can reverse the situation', 'defensive medicine practices', 'increasing violence against healthcare personnel', 'intense focus on specialization', 'low physician-to-patient ratio', 'overwhelmed physicians', 'primary care physicians', 'private marketplace', 'protect themselves by ordering unnecessary tests and procedures', 'results in delays in attending patients', 'set in', 'tempted to take on more patients than they can reasonably serve', 'thoughtful approach to government planning', 'underpaid physicians', 'unethical practices by pharmaceutical companies', 'will not be able to solve this'], ['accredit health facilities', 'enforcement of existing rules', 'health insurance scheme for central government employees', 'health system standardization', 'implementation of land allocation conditions', 'medical tourism hub', 'new rules for reasonable costs and cap profit margins', 'private health sector regulation', 'private health sector utilization'], ['accurate data about the quantity and geospatial location of its manpower', "central government's leadership in the fight for better health for all indians", 'live register for health personnel and infrastructure'], ['adoption', 'affordable, accessible, quality care', 'clinical and social skills', 'corporate houses', 'deeper structural problems', 'doctor-to-population ratio', 'erratic posting of personnel', 'evaluations', 'for-profit private health sector', 'government', 'government-funded health sector', 'health infrastructure', 'health personnel', 'health system', 'implementation', 'individualized mentoring', 'medical tourism', 'narayana health', 'national health mission (nhm)', 'non-hierarchical work environment', 'online training', 'out-of-pocket (oop) expenditure', 'out-of-pocket expenditure', 'overarching', 'patients', 'personnel retention', 'physicians', 'policy', 'primary care', 'private health sector', 'providing ongoing training', 'public and private health sectors', 'public health sector', 'public hospital beds', 'quality care', 'quality of care', 'quantum of services provided', 'recommendations made here', 'regulation', 'retaining', 'service provision', 'services they have been trained for', 'sourcing health personnel', 'strengthening', 'tier ii and iii cities', 'training', 'training initiative', 'transparency', 'transparency in creating training schedules', 'uniform standards', 'unmet demand for healthcare services', 'upgrading skills of nurses', 'vulnerable populations', 'well-equipped personnel', 'work environment', "world health organization's recommended"], ['ai-embedded logarithms now diagnose covid-19 disease from chest x-rays and ct scans', 'covid-19 pandemic catalyzing process and enabling delivery of healthcare', 'doctors can now perform an ophthalmic fundal examination online', 'drones being used to deliver medicines to communities', 'expanding application of technology to other portfolios within the health sector', 'innovations in digital technology supporting delivery of vital healthcare in high-income countries', 'manufacturing protective equipment locally using 3d printing', 'remote orthopedic examinations being used successfully', 'telemedicine for consultations with healthcare providers', 'uptake of telemedicine during covid-19 pandemic'], ['allocated budget to healthcare', 'ashas', 'ayush doctors', 'ayushman bharat', 'cadres', 'communities', 'communitization', 'contractors', 'contracts', 'contractual employees', 'contractual personnel', 'delayed', 'demotivation', 'doctors', 'economic norms', 'epidemiology/public health', 'financially protected from catastrophic health expenses', 'flexible financing', 'gdp', 'government of india', 'health policy', 'health sector reform', 'healthcare facilities', 'high-income countries', 'improved managem ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                               node    color  group
# 0                                      56 articles  #db57ac      1
# 1                                         analysis  #db57ac      1
# 2    corresponding authors' experiential knowledge  #db57ac      1
# 3                      extensive literature search  #db57ac      1
# 4                           peer-reviewed journals  #db57ac      1
# ..                                             ...      ...    ...
# 210                rural medical assistants (rmas)  #575edb     15
# 211                                 limited uptake  #9ddb57     16
# 212             national health protection mission  #9ddb57     16
# 213                  private health sector systems  #578ddb     17
# 214                                         public  #578ddb     17
#
# [215 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
